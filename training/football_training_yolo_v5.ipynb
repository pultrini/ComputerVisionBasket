# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.0/973.0 kB 1.2 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 3.2 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 5.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 5.9 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 7.2 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 6.1 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 3.1 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB ? eta 0:00:00 MB/s eta 0:00:010:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 6.7 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="WDPxz52HJCaqqtfdBxOx")
project = rf.workspace("test-datset").project("basketball-bs0zc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to BasketBall-1 in yolov5pytorch:: 100%|██████████| 18902/18902 [01:42<00:00, 184.70it/s]

# %%
dataset.location
# Out:
# '/home/manada/Documentos/Codes/Basketball_CV/training/BasketBall-1'

# %%
import shutil

shutil.move('BasketBall-1/train',
            'BasketBall-1/BasketBall-1/train')
shutil.move('BasketBall-1/valid',
            'BasketBall-1/BasketBall-1/valid')
shutil.move('BasketBall-1/test',
            'BasketBall-1/BasketBall-1/test')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[6], line 3
#       1 import shutil
# ----> 3 shutil.move('BasketBall-1/train',
#       4             'BasketBall-1/BasketBall-1/train')
#       5 shutil.move('BasketBall-1/valid',
#       6             'BasketBall-1/BasketBall-1/valid')
#       7 shutil.move('BasketBall-1/test',
#       8             'BasketBall-1/BasketBall-1/test')
#
# File /usr/lib/python3.10/shutil.py:814, in move(src, dst, copy_function)
#     811     real_dst = os.path.join(dst, _basename(src))
#     813     if os.path.exists(real_dst):
# --> 814         raise Error("Destination path '%s' already exists" % real_dst)
#     815 try:
#     816     os.rename(src, real_dst)
#
# Error: Destination path 'BasketBall-1/BasketBall-1/train/train' already exists

# %%
# !yolo task=detect mode=training model=yolov5x.pt data=(dataset.location)/data.yaml epochs=100 imgsz=640
